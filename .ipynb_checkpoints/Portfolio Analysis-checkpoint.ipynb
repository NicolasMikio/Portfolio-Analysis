# %%
import edhec_risk_kit as erk
import opcoes as opc
import yfinance as yf
import math
import matplotlib.pyplot as plt
import numpy as np
from time import time
import opcoes as opc
import pandas as pd
from datetime import date
plt.style.use('dark_background')
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
data = yf.download("ITSA4.SA PETR4.SA", start="2015-01-01", interval = "1d")
display(data)
# Out:
# [*********************100%***********************]  2 of 2 completed
#             Adj Close                 Close                  High             \
#              ITSA4.SA   PETR4.SA   ITSA4.SA   PETR4.SA   ITSA4.SA   PETR4.SA
# Date
# 2015-01-02   4.723387   8.683292   6.828494   9.360000   7.036998   9.990000
# 2015-01-05   4.738839   7.941133   6.850834   8.560000   6.955085   9.190000
# 2015-01-06   4.774894   7.681376   6.902959   8.280000   6.925299   8.830000
# 2015-01-07   4.955177   8.043180   7.163589   8.670000   7.267841   8.730000
# 2015-01-08   5.006687   8.562694   7.238055   9.230000   7.282734   9.390000
# ...               ...        ...        ...        ...        ...        ...
# 2021-03-22  10.500437  23.520000  10.520000  23.520000  10.550000  23.780001
# 2021-03-23  10.240920  22.799999  10.260000  22.799999  10.540000  23.629999
# 2021-03-24  10.031310  22.820000  10.050000  22.820000  10.310000  23.540001
# ...

# %%
x = opc.calcula_retornos(data)
x
# Out:
#             ITSA4.SA  PETR4.SA
# Date
# 2015-01-05  0.003272 -0.085470
# 2015-01-06  0.007609 -0.032710
# 2015-01-07  0.037756  0.047101
# 2015-01-08  0.010395  0.064590
# 2015-01-09 -0.034979  0.030336
# ...              ...       ...
# 2021-03-22  0.007663 -0.020000
# 2021-03-23 -0.024715 -0.030612
# 2021-03-24 -0.020468  0.000877
# 2021-03-25  0.020896  0.016652
# 2021-03-26  0.009747  0.011207
#
# [1543 rows x 2 columns]

# %%
xano = erk.annualize_rets(x, 12)
xano
# Out:
# ITSA4.SA    0.003247
# PETR4.SA    0.007172
# dtype: float64

# %%
cov = x.cov()
cov
# Out:
#           ITSA4.SA  PETR4.SA
# ITSA4.SA  0.000420  0.000416
# PETR4.SA  0.000416  0.001159

# %%
erk.plot_ef2(20, xano, cov)
# Out:
# <AxesSubplot:xlabel='Volatility'>
